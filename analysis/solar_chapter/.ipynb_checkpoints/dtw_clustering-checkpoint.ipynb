# %%
import numpy as np
import pandas as pd, os, datetime

# Statistical analysis
from scipy import stats
import math
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import pdist, squareform
from sklearn.metrics import silhouette_score
from tslearn.metrics import cdist_dtw

# plottinng
import matplotlib.pyplot as plt
from matplotlib import cm, colors
import folium

from IPython.display import HTML

# Import the loader function
os.chdir('/g/data/ng72/ms5578/ID_HW_BARRA')
from process_code import load_generation_data
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/torch/cuda/__init__.py:58: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.10/lib/python3.11/site-packages/distributed/diagnostics/nvml.py:14: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# Dask dashboard: /proxy/8787/status

# %%
df = pd.read_csv('/g/data/ng72/ms5578/ID_HW_BARRA/data/preprocess/wind_difference_curves.csv')

# %%
clust_df =  df[(df['cluster'] == 5) | (df['cluster'] == 2) | (df['cluster'] == 3) | (df['cluster'] == 0) | (df['cluster'] == 4)]
piv_df = clust_df.pivot_table(columns='hour', index='DUID', values='median_diff')

# %%
arr = piv_df.to_numpy() 
rows = piv_df.index.to_numpy()
hours = piv_df.columns.to_numpy()

# %%
full_mat = cdist_dtw(arr, arr)          # full (n, n) DTW distance matrix
distance_matrix = squareform(full_mat)  # condensed form for scipy.linkage

# distance_matrix = pdist(arr, metric='euclidean')   # condensed pairwise Euclidean distances
# full_mat = squareform(distance_matrix)             # full (n, n) distance matrix for silhouette

# %%
Z = linkage(distance_matrix, method='average')

# %%
plt.figure(figsize=(10, 4))
dendrogram(Z, truncate_mode=None, labels=rows if len(rows) <= 200 else None,
           leaf_rotation=90, leaf_font_size=6)
plt.title("Dendrogram")
plt.ylabel("Distance")
plt.tight_layout()
plt.show()

# %%
for k in range(2, 31):
    labels = fcluster(Z, t=k, criterion='maxclust') - 1
    unique_labels = np.unique(labels)
    n_clusters = len(unique_labels)
    n_samples = len(arr)

    if 1 < n_clusters < n_samples:
        try:
            sil = silhouette_score(full_mat, labels, metric='precomputed')
            print(f"Silhouette score (k={k}, clusters={n_clusters}): {sil:.3f}")
        except Exception as e:
            print(f"Silhouette score (k={k}, clusters={n_clusters}): error computing silhouette: {e}")
    else:
        reason = "only one cluster" if n_clusters <= 1 else "clusters == number of samples"
        print(f"Silhouette score (k={k}): not defined ({reason}, clusters={n_clusters}, samples={n_samples})")
# Out:
# Silhouette score (k=2, clusters=2): 0.632
# Silhouette score (k=3, clusters=3): 0.400
# Silhouette score (k=4, clusters=4): 0.356
# Silhouette score (k=5, clusters=5): 0.317
# Silhouette score (k=6, clusters=6): 0.263
# Silhouette score (k=7, clusters=7): 0.233
# Silhouette score (k=8, clusters=8): 0.195
# Silhouette score (k=9, clusters=9): 0.190
# Silhouette score (k=10, clusters=10): 0.173
# Silhouette score (k=11, clusters=11): 0.201
# Silhouette score (k=12, clusters=12): 0.209
# Silhouette score (k=13, clusters=13): 0.207
# Silhouette score (k=14, clusters=14): 0.178
# Silhouette score (k=15, clusters=15): 0.156
# Silhouette score (k=16, clusters=16): 0.157
# Silhouette score (k=17, clusters=17): 0.170
# Silhouette score (k=18, clusters=18): 0.161
# Silhouette score (k=19, clusters=19): 0.149
# Silhouette score (k=20, clusters=20): 0.144
# Silhouette score (k=21, clusters=21): 0.152
# Silhouette score (k=22, clusters=22): 0.159
# Silhouette score (k=23, clusters=23): 0.155
# Silhouette score (k=24, clusters=24): 0.137
# Silhouette score (k=25, clusters=25): 0.116
# Silhouette score (k=26, clusters=26): 0.107
# Silhouette score (k=27, clusters=27): 0.101
# Silhouette score (k=28, clusters=28): 0.093
# Silhouette score (k=29, clusters=29): 0.079
# Silhouette score (k=30, clusters=30): 0.073

# %%
k = 12
labels = fcluster(Z, t=k, criterion='maxclust') - 1
print(f"ACTUAL K SELECTED IS {k}")
# Out:
# ACTUAL K SELECTED IS 12

# %%
clusters_df = pd.DataFrame({'DUID': rows, 'cluster': labels}).set_index('DUID')
result = piv_df.copy()
result['cluster'] = clusters_df['cluster']  # aligns by index because rows == piv_df.index

# %%
duid_coords = pd.read_csv("/g/data/ng72/ms5578/ID_HW_BARRA/data/preprocess/gen_info.csv")[['DUID','lat','lon']]

map_df = result[['cluster']].merge(duid_coords[['lat','lon',"DUID"]], on='DUID', how='left')

missing = map_df[['lat','lon']].isna().any(axis=1).sum()
if missing:
    print(f"Warning: {missing} DUIDs have missing coordinates and will be skipped on the map")

valid = map_df.dropna(subset=['lat','lon']).copy()

# %%
# 5) Create interactive folium map colored by cluster
n_clusters_found = int(valid['cluster'].nunique())
cmap = cm.get_cmap('tab20', max(1, n_clusters_found))
norm = colors.Normalize(vmin=0, vmax=max(1, n_clusters_found - 1))

center = [valid['lat'].mean(), valid['lon'].mean()]
m = folium.Map(location=center, zoom_start=6, tiles='CartoDB.Positron')

for duid, row in valid.iterrows():
    cl = int(row['cluster'])
    rgba = cmap(norm(cl))
    color_hex = colors.rgb2hex(rgba[:3])
    popup = folium.Popup(f"DUID: {row['DUID']}<br>cluster: {cl}", parse_html=True)
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=5,
        color=color_hex,
        fill=True,
        fill_color=color_hex,
        fill_opacity=0.8,
        popup=popup
    ).add_to(m)

display(HTML(m._repr_html_()))
# Out:
# /jobfs/156731126.gadi-pbs/ipykernel_3438636/137021545.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', max(1, n_clusters_found))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8cd878a68392b93bfdf0fb67077a0c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8cd878a68392b93bfdf0fb67077a0c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8cd878a68392b93bfdf0fb67077a0c4 = L.map(
#                 &quot;map_f8cd878a68392b93bfdf0fb67077a0c4&quot;,
#                 {
#                     center: [-34.4310992518421, 142.83925986052634],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c8dab1aef1afa4b1589ef91a4b1115b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c8dab1aef1afa4b1589ef91a4b1115b.addTo(map_f8cd878a68392b93bfdf0fb67077a0c4);
#
#
#             var circle_marker_3e3b3f0641041ee6b0ff52f8781af1de = L.circleMarker(
#                 [-37.23851814, 143.07943056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e377c2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e377c2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f8cd878a68392b93bfdf0fb67077a0c4);
#
#
#         var popup_765fa62441b81381ccf9fb076be7739e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_564fc8b490b0e535fbba950da4159684 = $(`&lt;div id=&quot;html_564fc8b490b0e535fbba950da4159684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DUID: ARWF1&amp;lt;br&amp;gt;cluster: 7&lt;/div&gt;`)[0];
#                 popup_765fa62441b81381ccf9fb076be7739e.setContent(html_564fc8b490b0e535fbba950da4159684);
#
#
#
#         circle_marker_3e3b3f0641041ee6b0ff52f8781af1de.bindPopup(popup_765fa62441b81381ccf9fb076be7739e)
#         ;
#
#
#
#
#             var circle_marker_b72c1ffe391acac8dbec242cdab70333 = L.circleMarker(
#                 [-38.7908, 145.9277],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c5b0d5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c5b0d5&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f8cd878a68392b93bfdf0fb67077a0c4);
#
#
#         var popup_f29ac42a7269e23f6fba2141efd2ebd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_182420b110507e57af2b4d02bc71f125 = $(`&lt;div id=&quot;html_182420b110507e57af2b4d02bc71f125&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DUID: BALDHWF1&amp;lt;br&amp;gt;cluster: 5&lt;/div&gt;`)[0];
#                 popup_f29ac42a7269e23f6fba2141efd2ebd4.setContent(html_182420b110507e57af2b4d02bc71f125);
#
#
#
#         circle_marker_b72c1ffe391acac8dbec242cdab70333.bindPopup(popup_f29ac42a7269e23f6fba2141efd2ebd4)
#         ;
#
#
#
#
#             var circle_marker_536eb2638da7acf6d81e254d59d3646b = L.circleMarker(
#                 [-33.36933099999993, 138.98247600000002],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e377c2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e377c2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f8cd878a68392b93bfdf0fb67077a0c4);
#
#
#         var popup_b22e6cb93cf1a49a35f8e746a774abf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c65cd791f74b83cdc191d9439e62807 = $(`&lt;div id=&quot;html_6c65cd791f74b83cdc191d9439e62807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DUID: BLUFF1&amp;lt;br&amp;gt;cluster: 7&lt;/div&gt;`)[0];
#                 popup_b22e6cb93cf1a49a35f8e746a774abf2.setContent(html_6c65cd791f74b83cdc19

# %%
import seaborn as sns

sns.clustermap(
    piv_df,
    row_cluster=True,
    col_cluster=False,
    cmap='viridis',
    figsize=(11, 11),
    metric='euclidean',
    method='average',
    row_linkage=Z
)
plt.suptitle('Clustered IDs', y=1.02)
plt.show()
