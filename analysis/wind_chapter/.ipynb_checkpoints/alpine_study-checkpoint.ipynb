# %%
import numpy as np
import pandas as pd, os, datetime

# %%
import matplotlib.pyplot as plt
from matplotlib import cm, colors
import matplotlib.dates as mdates
import folium
from adjustText import adjust_text
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

from IPython.display import HTML

# %%
profs = pd.read_csv("/g/data/ng72/ms5578/ID_HW_BARRA/data/preprocess/wind_profile_clusters.csv")

# %%
clustered_info = pd.read_csv("/g/data/ng72/ms5578/ID_HW_BARRA/data/preprocess/wind_spatial_clusters.csv")

# %%
curves = pd.read_csv('/g/data/ng72/ms5578/ID_HW_BARRA/data/preprocess/wind_difference_curves.csv')
curves
# Out:
#       cluster      DUID  hour  mean_diff  mean_diff_lower  mean_diff_upper  \
# 0           0  BOCORWF1     0   0.047383        -0.188582         0.272302
# 1           0  BOCORWF1     1   0.091839        -0.155392         0.333684
# 2           0  BOCORWF1     2   0.133925        -0.117182         0.378320
# 3           0  BOCORWF1     3   0.169432        -0.081401         0.410586
# 4           0  BOCORWF1     4   0.223165        -0.029156         0.467538
# ...       ...       ...   ...        ...              ...              ...
# 1315        5  MUSSELR1    19  -0.186139        -0.337528        -0.029120
# 1316        5  MUSSELR1    20  -0.209915        -0.361429        -0.054157
# 1317        5  MUSSELR1    21  -0.215731        -0.367932        -0.061927
# 1318        5  MUSSELR1    22  -0.257422        -0.412463        -0.102307
# 1319        5  MUSSELR1    23  -0.262041        -0.422469        -0.102460
#
#       median_diff  median_diff_lower  median_diff_upper         station_name  \
# 0        0.123642          -0.246172           0.561812  Boco Rock Wind Farm
# 1        0.322653          -0.160928           0.719035  Boco Rock Wind Farm
# 2        0.399703          -0.012489           0.732188  Boco Rock Wind Farm
# 3        0.421769          -0.038441           0.859444  Boco Rock Wind Farm
# 4        0.382925           0.028880           0.880424  Boco Rock Wind Farm
# ...           ...                ...                ...                  ...
# 1315    -0.147246          -0.419948           0.102156  Musselroe Wind Farm
# 1316    -0.205077          -0.470687           0.021743  Musselroe Wind Farm
# 1317    -0.186293          -0.437389           0.052739  Musselroe Wind Farm
# 1318    -0.182080          -0.443415           0.022840  Musselroe Wind Farm
# 1319    -0.240811          -0.474616          -0.007462  Musselroe Wind Farm
#
#      cluster_name
# 0      Alpine NSW
# 1      Alpine NSW
# 2      Alpine NSW
# 3      Alpine NSW
# 4      Alpine NSW
# ...           ...
# 1315  Bass Strait
# 1316  Bass Strait
# 1317  Bass Strait
# 1318  Bass Strait
# 1319  Bass Strait
#
# [1320 rows x 11 columns]

# %%
df = profs.merge(clustered_info[['DUID','cluster','cluster_name','cluster_color']], on='DUID')
# Out:
#         DUID  profiles        lat         lon         profile_name  \
# 0      ARWF1         4 -37.238518  143.079431        No difference
# 1   BALDHWF1         4 -38.790800  145.927700        No difference
# 2     BLUFF1         4 -33.369331  138.982476        No difference
# 3   BOCORWF1         1 -36.576955  149.125867     Daytime increase
# 4     BODWF1         3 -32.414600  149.099795         Morning peak
# 5   BULGANA1         3 -37.118103  142.960530         Morning peak
# 6    CHYTWF1         4 -37.099382  145.267835        No difference
# 7   CLEMGPWF         3 -33.508568  138.119175         Morning peak
# 8   CNUNDAWF         1 -37.760253  140.403311     Daytime increase
# 9   COOPGWF1         5 -26.733227  151.472270          All-day low
# 10  CROOKWF2         3 -34.516500  149.542480         Morning peak
# 11  CROWLWF1         2 -37.121560  143.153715    Evening reduction
# 12   CRURWF1         4 -33.005358  149.616812        No difference
# 13   CTHLWF1         2 -42.159931  146.708927    Evening reduction
# 14   DULAWF1         6 -26.637084  149.871046  Night-time increase
# 15  ELAINWF1         1 -37.635595  144.024737     Daytime increase
# 16   GRANWF1         4 -41.782720  145.048720        No difference
# 17  GULLRWF1         4 -34.614456  149.459531        No difference
# 18  GUNNING1         4 -34.697734  149.386126        No difference
# 19   HALLWF1         2 -33.348652  138.751659    Evening reduction
# 20   HALLWF2         2 -33.348652  138.751659    Evening reduction
# 21     HDWF1         3 -33.042878  138.556285         Morning peak
# 22     HDWF2         3 -33.042878  138.556285         Morning peak
# 23     HDWF3         3 -33.042839  138.556216         Morning peak
# 24  KABANWF1         5 -17.560364  145.413271          All-day low
# 25    KEPWF1         5 -20.938150  144.371336          All-day low
# 26  KIATAWF1         3 -36.396583  141.747383         Morning peak
# 27   LGAPWF1         2 -32.564508  137.557192    Evening reduction
# 28   LGAPWF2         3 -32.564508  137.557192         Morning peak
# 29  LKBONNY1         1 -37.781546  140.405792     Daytime increase
# 30  LKBONNY2         3 -37.814894  140.419499         Morning peak
# 31  LKBONNY3         3 -37.750496  140.393029         Morning peak
# 32  MACARTH1         3 -38.064804  142.184360         Morning peak
# 33  MERCER01         2 -37.841111  143.871111    Evening reduction
# 34     MEWF1         5 -17.167500  145.387370          All-day low
# 35  MTGELWF1         4 -38.258691  143.801944        No difference
# 36  MUSSELR1         2 -40.779811  148.009739    Evening reduction
# 37   MUWAWF1         6 -36.433261  142.318190  Night-time increase
# 38    NBHWF1         2 -33.252576  138.712289    Evening reduction
# 39  OAKLAND1         2 -37.687059  142.546725    Evening reduction
# 40  SALTCRK1         4 -37.926755  142.771479        No difference
# 41   SAPHWF1         5 -29.699726  151.411940          All-day low
# 42  SNOWNTH1         2 -33.713956  138.140174    Evening reduction
# 43  SNOWSTH1         3 -33.830164  138.118444         Morning peak
# 44  SNOWTWN1         3 -33.711237  138.145557         Morning peak
# 45  STARHLWF         6 -35.567765  138.143238  Night-time increase
# 46     STWF1         2 -31.806761  141.268646    Evening reduction
# 47  TARALGA1         4 -34.427076  149.857640        No difference
# 48  WATERLWF         2 -34.001025  138.910932    Evening reduction
# 49     WGWF1         2 -33.393049  138.844777    Evening reduction
# 50  WOODLWN1         4 -35.086060  149.571606        No difference
# 51      WPWF         1 -35.110350  137.705778     Daytime increase
# 52     WRWF1         4 -29.846500  151.573260        No difference
# 53   YENDWF1         3 -37.631438  144.020788         Morning peak
#
#    profile_color  cluster      cluster_name cluster_color
# 0        #d62728        3     West Victoria       #ffd92f
# 1        #d62728        5       Bass Strait       #66c2a5
# 2        #d62728        1   South Australia       #8da0cb
# 3        #1f77b4        0        Alpine NSW       #e78ac3
# 4        #2ca02c        0        Alpine NSW       #e78ac3
# 5        #2ca02c        3     West Victoria       #ffd92f
# 6        #d62728        3     West Victoria       #ffd92f
# 7        #2ca02c        1   South Australia       #8da0cb
# 8        #1f77b4        3     West Victoria       #ffd92f
# 9        #9467bd        4   Eastern Central       #a6d854
# 10       #2ca02c        0        Alpine NSW       #e78ac3
# 11       #ff7f0e        3     West Victoria       #ffd92f
# 12       #d62728        0        Alpine NSW       #e78ac3
# 13       #ff7f0e        5       Bass Strait       #66c2a5
# 14       #8c564b        4   Eastern Central       #a6d854
# 15       #1f77b4        3     West Victoria       #ffd92f
# 16       #d62728        5       Bass Strait       #66c2a5
# 17       #d62728        0        Alpine NSW       #e78ac3
# 18       #d62728        0        Alpine NSW       #e78ac3
# 19       #ff7f0e        1   South Australia       #8da0cb
# 20       #ff7f0e        1   South Australia       #8da0cb
# 21       #2ca02c        1   South Australia       #8da0cb
# 22       #2ca02c        1   South Australia       #8da0cb
# 23       #2ca02c        1   South Australia       #8da0cb
# 24       #9467bd        2  North Queensland       #fc8d62
# 25       #9467bd        2  North Queensland       #fc8d62
# 26       #2ca02c        3     West Victoria       #ffd92f
# 27       #ff7f0e        1   South Australia       #8da0cb
# 28       #2ca02c        1   South Australia       #8da0cb
# 29       #1f77b4        3     West Victoria       #ffd92f
# 30       #2ca02c        3     West Victoria       #ffd92f
# 31       #2ca02c        3     West Victoria       #ffd92f
# 32       #2ca02c        3     West Victoria       #ffd92f
# 33       #ff7f0e        3     West Victoria       #ffd92f
# 34       #9467bd        2  North Queensland       #fc8d62
# 35       #d62728        3     West Victoria       #ffd92f
# 36       #ff7f0e        5       Bass Strait       #66c2a5
# 37       #8c564b        3     West Victoria       #ffd92f
# 38       #ff7f0e        1   South Australia       #8da0cb
# 39       #ff7f0e        3     West Victoria       #ffd92f
# 40       #d62728        3     West Victoria       #ffd92f
# 41       #9467bd        4   Eastern Central       #a6d854
# 42       #ff7f0e        1   South Australia       #8da0cb
# 43       #2ca02c        1   South Australia       #8da0cb
# 44       #2ca02c        1   South Australia       #8da0cb
# 45       #8c564b        1   South Australia       #8da0cb
# 46       #ff7f0e        1   South Australia       #8da0cb
# 47       #d62728        0        Alpine NSW       #e78ac3
# 48       #ff7f0e        1   South Australia       #8da0cb
# 49       #ff7f0e        1   South Australia       #8da0cb
# 50       #d62728        0        Alpine NSW       #e78ac3
# 51       #1f77b4        1   South Australia       #8da0cb
# 52       #d62728        4   Eastern Central       #a6d854
# 53       #2ca02c        3     West Victoria       #ffd92f

# %%
cluster_id = 0
dfc = df[df["cluster"] == cluster_id]

# %%
# -------------------
# Auto-zoom extent with padding
# -------------------
pad_lon = 2
pad_lat = 0.5
lon_min, lon_max = dfc["lon"].min() - pad_lon, dfc["lon"].max() + pad_lon
lat_min, lat_max = dfc["lat"].min() - pad_lat, dfc["lat"].max() + pad_lat

# -------------------
# Create figure
# -------------------
fig = plt.figure(figsize=(6, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

# Base map
ax.add_feature(cfeature.LAND, facecolor="lightgrey")
ax.add_feature(cfeature.STATES, linewidth=0.2)
ax.add_feature(cfeature.COASTLINE, linewidth=0.8)
ax.set_extent([lon_min, lon_max, lat_min, lat_max], crs=ccrs.PlateCarree())

# -------------------
# Plot points
# -------------------
sc = ax.scatter(
    dfc["lon"],
    dfc["lat"],
    c=dfc["profile_color"],
    s=90,
    transform=ccrs.PlateCarree(),
    zorder=5,
)

texts = []
for _, r in dfc.iterrows():
    texts.append(
        ax.text(
            r["lon"],
            r["lat"],
            r["DUID"],
            fontsize=9,
            transform=ccrs.PlateCarree(),
            zorder=6,
            bbox=dict(facecolor="white", edgecolor="none", alpha=0.8, pad=1),
        )
    )

# -------------------
# Adjust labels to avoid overlap
# -------------------
adjust_text(
    texts,
    x=dfc["lon"].values,          # points to repel from
    y=dfc["lat"].values,
    ax=ax,
    force_text=(0.7, 0.5),        # stronger text–text repulsion
    force_static=(1.0, 0.7),      # stronger text–point repulsion
    expand=(3, 2),            # expand text bboxes for collision
    min_arrow_len=0.3,
    arrowprops=dict(
        arrowstyle="-",
        lw=0.5,
        shrinkA=6,
        shrinkB=6,
    ),
)

# -------------------
# Title
# -------------------
ax.set_title(dfc.iloc[0]["cluster_name"])
plt.show()

# %%
cluster_id = 0
df_cluster = curves[curves["cluster"] == cluster_id]
df_cluster = df_cluster.merge(
    profs[["DUID", "profile_color", "profile_name"]],
    on="DUID",
    how="left"
)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for duid, group in df_cluster.groupby("DUID"):
    plt.plot(
        group["hour"],
        group["median_diff"],
        label=duid,
        color=group["profile_color"].iloc[0]
    )
    plt.fill_between(
        group["hour"],
        group["median_diff_lower"],
        group["median_diff_upper"],
        color=group["profile_color"].iloc[0],
        alpha=0.2
    )

plt.xlabel("Hour")
plt.ylabel("Mean Difference")
plt.title(f"Cluster {cluster_id} - {group['cluster_name'].iloc[0]}")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Unique DUIDs in cluster
duids = df_cluster["DUID"].unique()
n = len(duids)

# Number of columns
ncols = 3
nrows = int(np.ceil(n / ncols))

# Figure and axes
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6*ncols, 3*nrows), sharex=True)
axes = axes.flatten()

# Compute global y-limits for the cluster
ymin = df_cluster["median_diff_lower"].min()
ymax = df_cluster["median_diff_upper"].max()
padding = (ymax - ymin) * 0.05  # 5% padding
ymin -= padding
ymax += padding

# Plot each DUID
for ax, duid in zip(axes, duids):
    group = df_cluster[df_cluster["DUID"] == duid]
    
    # Line
    ax.plot(
        group["hour"],
        group["median_diff"],
        color=group["profile_color"].iloc[0],
        label=duid
    )
    
    # Shaded uncertainty
    ax.fill_between(
        group["hour"],
        group["median_diff_lower"],
        group["median_diff_upper"],
        color=group["profile_color"].iloc[0],
        alpha=0.2
    )
    
    ax.set_title(f"{duid} ({group['profile_name'].iloc[0]})")
    ax.set_ylabel("Mean Difference")
    ax.set_ylim(ymin, ymax)  # same y-scale for all
    ax.grid(True)

# Hide unused axes
for ax in axes[n:]:
    ax.set_visible(False)

# Shared x-axis label
for ax in axes[-ncols:]:
    ax.set_xlabel("Hour")

plt.tight_layout()
plt.show()
